# %% [markdown]
# # import dataset from urllib.request()

# %%
from urllib.request import urlretrieve

# %%
urlretrieve("https://www.kaggle.com/shivamb/netflix-shows")
# Out:
# ('/tmp/tmpe4uu3sry', <http.client.HTTPMessage at 0x7f8a1817e3a0>)

# %% [markdown]
# # Lets verify datasets are downloaded in directory

# %%
import os

# %%
os.listdir()
# Out:
# ['.profile',
#  '.bashrc',
#  '.bash_logout',
#  '.jovianrc',
#  '.local',
#  'data_analysis_project.ipynb',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  '.jovian',
#  '.ipython',
#  '.cache',
#  '.git',
#  '.yarn',
#  '.empty',
#  '.config',
#  'netflix_titles.csv',
#  '.conda',
#  'work']

# %% [markdown]
# # Import pandas for dataframes

# %%
import pandas as pd

# %%
movies_df = pd.read_csv('netflix_titles.csv')

# %%
type(movies_df)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %% [markdown]
# # To display list of columns

# %%
movies_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
movies_df.tail()
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %%
movies_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # We can view some basic information about the data frame using the .info method.

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit(project='data_analysis_project')

# %% [markdown]
# # Data cleaning and preparing

# %%
movies_df["date_added"]=movies_df["date_added"].str.replace(",", "").str.strip() ## Strip removes spaces front and back
movies_df["date_added"]=pd.to_datetime(movies_df["date_added"], format="%B %d %Y")

movies_df["director"]=movies_df["director"].fillna("Unknown")
movies_df["cast"]=movies_df["cast"].fillna("Unknown")
movies_df["country"]=movies_df["country"].fillna("Unknown")


movies_df["Season"]=""

columns_name=["show_id", "type", "title", 
              "director", "cast", "country",
              "date_added", "release_year", "rating",
              "duration", "Season", "listed_in", "description"]
movies_df=movies_df.reindex(columns=columns_name)

movies_df["Season"] = movies_df[movies_df["duration"].str.contains("Season")]["duration"] ## Separating Season from duration

## Make a Season Column an Integer

movies_df["Season"]=movies_df["Season"].fillna("0")
movies_df["Season"]=movies_df["Season"].str.replace("Season", "").str.replace("s", "")
movies_df["Season"]=movies_df["Season"].astype(str).astype(int)

## Make a duration column an Integer
movies_df["duration"]=movies_df.duration.str.replace('^(\d+)(.Seasons*)$', "0") ## Remove The Season from the column
movies_df["duration"]=movies_df["duration"].str.replace(" min", "") ## Remove min
movies_df["duration"]=movies_df["duration"].astype(int) ## Convert to Integer



movies_df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                      Unknown
# 2                      Unknown
# ...

# %%
selected_columns = ['show_id','title','director','cast','country','date_added','release_year',
                    'rating','duration','listed_in','description']

# %%
len(selected_columns)
# Out:
# 11

# %%
movies_df.shape
# Out:
# (6234, 13)

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      6234 non-null   object
#  4   cast          6234 non-null   object
#  5   country       6234 non-null   object
#  6   date_added    6223 non-null   datetime64[ns]
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   int64
#  10  Season        6234 non-null   int64
#  11  listed_in     6234 non-null   object
#  12  description   6234 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 633.3+ KB

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "nc59774/data-analysis-project" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/nc59774/data-analysis-project
# 'https://jovian.ai/nc59774/data-analysis-project'

# %% [markdown]
# # Importing required libraries

# %%
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies_df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      11
# release_year     0
# rating          10
# duration         0
# Season           0
# listed_in        0
# description      0
# dtype: int64

# %%
movies_df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                      Unknown
# 2                      Unknown
# ...

# %% [markdown]
# # Q.1 How many categories in a particular column ?

# %%
movies_df['type'].value_counts()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
movies_df['listed_in'].value_counts()
# Out:
# Documentaries                                                             299
# Stand-Up Comedy                                                           273
# Dramas, International Movies                                              248
# Dramas, Independent Movies, International Movies                          186
# Comedies, Dramas, International Movies                                    174
#                                                                          ...
# Independent Movies, Romantic Movies                                         1
# Action & Adventure, Cult Movies                                             1
# Classic Movies, Dramas, LGBTQ Movies                                        1
# Classic Movies, Comedies, Romantic Movies                                   1
# British TV Shows, International TV Shows, Stand-Up Comedy & Talk Shows      1
# Name: listed_in, Length: 461, dtype: int64

# %%
movies_df['rating'].value_counts()
# Out:
# TV-MA       2027
# TV-14       1698
# TV-PG        701
# R            508
# PG-13        286
# NR           218
# PG           184
# TV-Y7        169
# TV-G         149
# TV-Y         143
# TV-Y7-FV      95
# G             37
# UR             7
# NC-17          2
# Name: rating, dtype: int64

# %%
movies_df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      11
# release_year     0
# rating          10
# duration         0
# Season           0
# listed_in        0
# description      0
# dtype: int64

# %%
movies_df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      11
# release_year     0
# rating           0
# duration         0
# Season           0
# listed_in        0
# description      0
# dtype: int64

# %%
movies_df['rating'].replace(np.NaN, 'TV-MA', inplace=True)

# %%
movies_df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                      Unknown
# 2                      Unknown
# ...

# %%
movies_df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      11
# release_year     0
# rating           0
# duration         0
# Season           0
# listed_in        0
# description      0
# dtype: int64

# %% [markdown]
# # Above we have replaced all the Null(NaN) values with respective field

# %% [markdown]
# # Visualizing the dataset

# %% [markdown]
# # Q.3 What are the different types of shows Netflix have?

# %%
sns.countplot(x='type',data=movies_df)
plt.title('Typeof Netlfix Shows')
# Out:
# Text(0.5, 1.0, 'Typeof Netlfix Shows')

# %% [markdown]
# # Q.4 Visualize different rating of TV show and Movies

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="rating", data=movies_df, palette="Set2", order=movies_df['rating'].value_counts().index[0:15])

# %% [markdown]
# # Q.5 Visualize the year wise analysis of the Netflix Shows?

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="release_year", data=movies_df, palette="Set2", order=movies_df['release_year'].value_counts().index[0:15])

# %% [markdown]
# # Q.6 Frequency of movies released in different year

# %%
plt.figure(figsize=(16,8))
movies_df[movies_df["type"]=="Movie"]["release_year"].value_counts()[:20].plot(kind="bar",color="green")
plt.title("Frequency of Movies which were released in different years and are available on Netflix");

# %%
plt.figure(figsize=(12,6))
movies_df[movies_df["type"]=="TV Show"]["release_year"].value_counts()[:20].plot(kind="bar",color="yellow")
plt.title("Frequency of TV shows which were released in different years and are available on Netflix")
# Out:
# Text(0.5, 1.0, 'Frequency of TV shows which were released in different years and are available on Netflix')

# %%
df_countries = pd.DataFrame(movies_df.country.value_counts().reset_index().values, columns=["country", "count"])
df_countries.head()
# Out:
#           country count
# 0   United States  2032
# 1           India   777
# 2         Unknown   476
# 3  United Kingdom   348
# 4           Japan   176

# %%
import jovian
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "nc59774/data-analysis-project" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/nc59774/data-analysis-project
# 'https://jovian.ai/nc59774/data-analysis-project'

# %% [markdown]
# # Horror movies on Netlfix

# %%
((movies_df["listed_in"].str.contains("Horror"))[(movies_df["type"]=="Movie")]).sum()
# Out:
# 262

# %% [markdown]
# # Horror TV shows on Netflix

# %%
((movies_df['listed_in'].str.contains('Horror'))[(movies_df['type']=='TV Show')]).sum()
# Out:
# 54

# %% [markdown]
# # Q.7 What is the average duration of the movie ?

# %%
sort= movies_df["duration"]!=0
movies_df[sort]["duration"].median()
# Out:
# 98.0

# %% [markdown]
# # Maximum duration of the movie on Netlfix ?

# %%
movies_df["duration"].max()
# Out:
# 312

# %%
movies_df[movies_df["duration"]==312]
# Out:
#        show_id   type                       title director  \
# 4315  80988062  Movie  Black Mirror: Bandersnatch  Unknown
#
#                                                    cast        country  \
# 4315  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#      date_added  release_year rating  duration  Season  \
# 4315 2018-12-28          2018  TV-MA       312       0
#
#                                            listed_in  \
# 4315  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                             description
# 4315  In 1984, a young programmer begins to question...

# %%
movies_df['Season'].max()
# Out:
# 15

# %%
movies_df[movies_df['Season']==15]
# Out:
#        show_id     type           title director  \
# 5908  70140391  TV Show  Grey's Anatomy  Unknown
# 5974  70142386  TV Show            NCIS  Unknown
#
#                                                    cast        country  \
# 5908  Ellen Pompeo, Sandra Oh, Katherine Heigl, Just...  United States
# 5974  Mark Harmon, Michael Weatherly, Pauley Perrett...  United States
#
#      date_added  release_year rating  duration  Season  \
# 5908 2019-06-15          2018  TV-14         0      15
# 5974 2018-07-01          2017  TV-14         0      15
#
#                                     listed_in  \
# 5908             Romantic TV Shows, TV Dramas
# 5974  Crime TV Shows, TV Dramas, TV Mysteries
#
#                                             description
# 5908  Intern (and eventual resident) Meredith Grey f...
# 5974  Follow the quirky agents of the NCIS – the Nav...

# %% [markdown]
# # Which is the oldest movie on Netflix?

# %%
oldest_movies=movies_df['type']=="Movie"
movies_df[oldest_movies].sort_values(by="release_year", ascending= True).head(5)
# Out:
#        show_id   type                                          title  \
# 2013  60027942  Movie                           The Battle of Midway
# 2011  60027945  Movie                                 Prelude to War
# 2023  70013050  Movie             Why We Fight: The Battle of Russia
# 2026  70022548  Movie                WWII: Report from the Aleutians
# 2022  80119186  Movie  Undercover: How to Operate Behind Enemy Lines
#
#                          director                       cast        country  \
# 2013                    John Ford  Henry Fonda, Jane Darwell  United States
# 2011                  Frank Capra                    Unknown  United States
# 2023  Frank Capra, Anatole Litvak                    Unknown  United States
# 2026                  John Huston                    Unknown  United States
# 2022                    John Ford                    Unknown  United States
#
#      date_added  release_year rating  duration  Season  \
# ...

# %%
oldest_tvshow  = movies_df['type']=='TV Show'
movies_df[oldest_tvshow].sort_values(by='release_year', ascending= True).head(5)
# Out:
#        show_id     type                                title  \
# 4292  81030762  TV Show    Pioneers: First Women Filmmakers*
# 4079  80161851  TV Show  Pioneers of African-American Cinema
# 5981  70172488  TV Show  The Twilight Zone (Original Series)
# 5980  70155574  TV Show               The Andy Griffith Show
# 5704  70136140  TV Show                            Star Trek
#
#                                                director  \
# 4292                                            Unknown
# 4079  Oscar Micheaux, Spencer Williams, Richard E. N...
# 5981                                            Unknown
# 5980                                            Unknown
# 5704                                            Unknown
#
#                                                    cast        country  \
# 4292                                            Unknown        Unknown
# 4079                                            Unknown  United States
# ...

# %% [markdown]
# # Countries and  Movie releases

# %%
(movies_df[movies_df["type"]=="Movie"]
.groupby("country")
[["show_id"]]
.count()
.sort_values(by="show_id", ascending=False)
.head(10)
)
# Out:
#                 show_id
# country
# United States      1482
# India               724
# Unknown             195
# United Kingdom      170
# Canada               88
# Spain                80
# Turkey               55
# Mexico               54
# France               50
# Hong Kong            49

# %% [markdown]
# # Countries and TV Shows releases

# %%
(movies_df[movies_df["type"]=="TV Show"]
.groupby("country")
[["show_id"]]
.count()
.sort_values(by="show_id", ascending=False)
.head(10)
)
# Out:
#                 show_id
# country
# United States       550
# Unknown             281
# United Kingdom      178
# Japan               129
# South Korea         104
# Taiwan               65
# India                53
# Canada               53
# France               40
# Australia            39

# %%
# Is there any movies of my favourite hero ? Eg. Tom Cruise

# %%
(movies_df['cast'].str.contains('Tom Cruise')).sum()
movies_df[movies_df['cast'].str.contains('Tom Cruise')]
# Out:
#        show_id   type     title              director  \
# 3071  60029369  Movie  Rain Man        Barry Levinson
# 3538  60000440  Movie  Magnolia  Paul Thomas Anderson
#
#                                                    cast        country  \
# 3071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
# 3538  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
#
#      date_added  release_year rating  duration  Season  \
# 3071 2019-07-01          1988      R       134       0
# 3538 2020-01-01          1999      R       189       0
#
#                        listed_in  \
# 3071      Classic Movies, Dramas
# 3538  Dramas, Independent Movies
#
#                                             description
# 3071  A fast-talking yuppie is forced to slow down w...
# 3538  Through chance, human action, past history and...

# %% [markdown]
# # Is there any "Will Smith" movies?

# %%
(movies_df['cast'].str.contains("Will Smith")).sum()
movies_df[movies_df['cast'].str.contains('Will Smith')]
# Out:
#        show_id     type                     title          director  \
# 622   60001650    Movie              Men in Black  Barry Sonnenfeld
# 781     269880    Movie                  Bad Boys       Michael Bay
# 782   60029167    Movie               Bad Boys II       Michael Bay
# 810   60023597    Movie           Men in Black II  Barry Sonnenfeld
# 836   70044605    Movie  The Pursuit of Happyness  Gabriele Muccino
# 3522  70019506    Movie                     Hitch      Andy Tennant
# 3598  22007250    Movie            Wild Wild West  Barry Sonnenfeld
# 3889  81071666  TV Show          One Strange Rock           Unknown
# 4383  80119234    Movie                    Bright        David Ayer
# 4672  70104313    Movie              Seven Pounds  Gabriele Muccino
#
#                                                    cast        country  \
# 622   Tommy Lee Jones, Will Smith, Linda Fiorentino,...  United States
# 781   Will Smith, Martin Lawrence, Téa Leoni, Tchéky...  United States
# ...

# %% [markdown]
# # IS there any Angelina Jolie movies?

# %%
(movies_df['cast'].str.contains('Angelina Jolie')).sum()
movies_df[movies_df['cast'].str.contains('Angelina Jolie')]
# Out:
#        show_id     type                                     title  \
# 3033  70241791  TV Show  DreamWorks Kung Fu Panda Awesome Secrets
# 3196  70142888    Movie                               The Tourist
# 4722  70253397    Movie                    Kung Fu Panda: Holiday
#
#                               director  \
# 3033                           Unknown
# 3196  Florian Henckel von Donnersmarck
# 4722                       Tim Johnson
#
#                                                    cast  \
# 3033  Jack Black, Dustin Hoffman, Dennis Haysbert, P...
# 3196  Angelina Jolie, Johnny Depp, Paul Bettany, Tim...
# 4722  Jack Black, Angelina Jolie, Dustin Hoffman, Ja...
#
#                                            country date_added  release_year  \
# 3033                                 United States 2019-07-01          2008
# 3196  United States, France, Italy, United Kingdom 2020-01-07          2010
# 4722                                 United States 2012-12-01          2010
#
# ...
